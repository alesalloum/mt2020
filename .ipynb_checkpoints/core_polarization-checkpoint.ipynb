# %%
import networkx as nx
import matplotlib.pyplot as plt
import pickle
import numpy as np
import random
from scipy.stats import wasserstein_distance, energy_distance
from matplotlib.backends.backend_pdf import PdfPages
import json
import pandas as pd

# %%
SAVE_MODE = 0

# %% [markdown]
# ### I. Load the data

# %%
def easier_indexing(Gs):
    """
        Quick tool for easier indexing 
    """
    keys = [Gs[i][1][:-5] for i in range(len(Gs))]
    topic_dict = dict(zip(keys, list(range(len(keys)))))
    return topic_dict

# %%
GL = pickle.load(open("data/graphlistnew.pickle", "rb" ))
topic_dict = easier_indexing(GL)

# %% [markdown]
# ### II. Identify the cores

# %%
def find_main_core(G, k=None):
    
    core_subgraph = nx.k_core(G, k=None, core_number=None)
    
    return core_subgraph

# %%
def get_colormap(G, core_subgraph, colors):
    
    color_map = []
    for node in G:
        if node in core_subgraph.nodes():
            color_map.append(color[0])
        else: 
            color_map.append(color[1]) 
    
    return color_map

# %%
def find_n_cores(network, n):
    
    colorlist = ["red", "blue", "orange", "green", "yellow", "brown"]
    cores = dict()
    
    G = network.copy()
    
    for i in range(n):
    
        cores[i] = find_main_core(G)
        
        for node in cores[i].nodes:
            G.remove_node(node)
           
    return cores

# %%
def color_cores(cores, network):
    
    color_map = []

    for node in network:
        if node in cores[0]:
            color_map.append("red")
        elif node in cores[1]:
            color_map.append("blue")
        else: 
            color_map.append("gray") 
    
    return color_map

# %% [markdown]
# ### III. Measure the core polarization

# %% [markdown]
# 1. Updated random walk based score. Pick from each cores the node with highest closeness centrality to be influencer. Start random walk.

# %%
def perform_randomwalk(G, starting_node, li, ri):
    
    found = 0
    end_side = 0
    which_random_starting_node = starting_node
   
    while (found != 1):
        neighbors = list(G.neighbors(which_random_starting_node))
        next_node = random.choice(neighbors)
        if (next_node in li):
            end_side = "A"
            found = 1  
        elif (next_node in ri):
            end_side = "B"
            found = 1
        else:
            which_random_starting_node = next_node       
    return end_side

def random_walk(backbone, cores, n_iter):
    
    centrality_core1 = nx.closeness_centrality(cores[0])
    centrality_core2 = nx.closeness_centrality(cores[1])
    
    A = max(centrality_core1, key=centrality_core1.get)
    B = max(centrality_core2, key=centrality_core2.get)
    
    AA = 0
    AB = 0
    BB = 0
    BA = 0
    
    starting_nodes = random.choices(list(cores[0]) + list(cores[1]), k=n_iter)
    
    for node in starting_nodes:
        
        res = perform_randomwalk(backbone, node, [A], [B])
        
        if node in cores[0] and res == "A":
            AA += 1
        
        elif node in cores[0] and res == "B":
            AB += 1
            
        elif node in cores[1] and res == "B":
            BB += 1
            
        elif node in cores[1] and res == "A":
            BA += 1
            
        else:
            print("Not possible!")
            
            
    pAA = AA/(AA+AB)
    pAB = 1-pAA
    
    pBB = BB/(BB+BA)
    pBA = 1-pBB
        
    
    return(pAA*pBB - pAB*pBA)

# %% [markdown]
# 2. Accessibility (flow) based score, where p=0.5 and k=3. **A** measures the expected number of times that node **v** will hear about a cascade originating at node **u**, using walks of length up to **k**. The distance between the core-specific distributions is measured with *wasserstein* metric.

# %%
def accessibility_score(backbone, cores, p=0.5):
    
    nodelist = list(cores[0]) + list(cores[1])
    M = nx.to_numpy_matrix(backbone, nodelist=nodelist)
    
    A = p*M + p**2 * M**2 + p**3*M**3
    n_core1 = len(cores[0])
    
    core1_intra = A[:n_core1, :n_core1].flatten().tolist()[0]
    core2_intra = A[n_core1:, n_core1:].flatten().tolist()[0]
    core_inter = A[:n_core1, n_core1:].flatten().tolist()[0]
    
    EMD = wasserstein_distance(core1_intra + core2_intra, core_inter)
    ENR = energy_distance(core1_intra + core2_intra, core_inter)
    
    return(np.var(A), EMD, ENR)

# %% [markdown]
# 3. Assortativity

# %%
def assortativity(backbone):
    r=nx.degree_assortativity_coefficient(backbone)
    return r

# %% [markdown]
# 4. Spectral approach

# %%
def algebraic_connectivity(backbone):
    
    ac = nx.algebraic_connectivity(backbone)
    normalized_ac = nx.algebraic_connectivity(backbone, normalized=True)
    
    return (ac, normalized_ac)

# %% [markdown]
# ### IV. Analytical pipeline

# %%
spectral_snails = ["jotainrajaa", "samasuunta", "piraatit"]
disconnected_cores = ["vaalikone"]

# %%
def compute_core_polarization(net):
    
    G = net.copy()
    
    # Remove self-retweets
    G.remove_edges_from(nx.selfloop_edges(G))
    
    # Find two cores
    cores = find_n_cores(G, 2)
    
    # Take core subgraph
    backbone_nodes = (nx.compose_all(cores.values())).nodes
    backbone = G.subgraph(backbone_nodes)
    
    # Save values into a dictionary
    score_dict = dict()
    
    if t not in disconnected_cores:
        score_dict["RW"] = random_walk(backbone, cores, 1000)
        #print("RW completed.")
    else:
        score_dict["RW"] = 0
        #print("Disconnected core detected...")
    
    if t not in spectral_snails:
        score_dict["AC"] = algebraic_connectivity(backbone)[0]
        score_dict["nAC"] = algebraic_connectivity(backbone)[1]
        #print("AC completed.")
    else:
        score_dict["AC"] = (0,0)
        #print("Snail detected...")
        
    score_dict["varFLOW"] = accessibility_score(backbone, cores)[0]
    score_dict["wasFLOW"] = accessibility_score(backbone, cores)[1]
    score_dict["eneFLOW"] = accessibility_score(backbone, cores)[2]
    #print("FLOW completed.")
    
    score_dict["ASSOR"] = assortativity(backbone)
    #print("ASSOR completed.")

    return score_dict

# %% [markdown]
# Compute the core polarization scores for selected topics

# %%
core_polarization = dict()

# %%
all_topics = list(topic_dict.keys())

polarized_topics = ["kokoomus", 
                    "vihreät", 
                    "perussuomalaiset", 
                    "vasemmisto", 
                    "vihapuhe", 
                    "ilmastonmuutos", 
                    "maahanmuutto",
                    "sote",
                    "ilmastovaalit"]

unpolarized_topics = ["mielenterveys", 
                      "liikenne", 
                      "kunnat", 
                      "tekoäly", 
                      "nuoret", 
                      "urheilu", 
                      "yrittäjät",
                      "yrittäjyys",
                      "rekry",
                      "osaaminen",
                      "johtaminen"]

# %%
for t in all_topics:
    
    print("Starting to process the topic: ", t)
    #Load the network
    network = GL[topic_dict[t]][0][0][0]
    
    #Compute all scores for core polarization
    core_polarization[t] = compute_core_polarization(network)

    print("Following topic completed: : ", t)
    print("\n")

# %%
if SAVE_MODE:

    # Save results to file
    with open('results2.json', 'w') as fp:
        json.dump(core_polarization, fp)

# %% [markdown]
# ### V. Visualization pipeline

# %% [markdown]
# *later*

# %% [markdown]
# ### VI. Results

# %% [markdown]
# ORDER

# %%
df = pd.DataFrame.from_dict(core_polarization).T
df
# Out:
#                              RW         AC         nAC  varFLOW   wasFLOW  \
# aktiivimalli           0.250084    1.96503    0.248907  30.6049   6.54326
# ammatillinenkoulutus   0.661588   0.358265    0.102289  35.6484   8.22197
# arvot                  0.442593   0.131889   0.0231745  2.20834  0.964025
# demokratia             0.673865   0.197761   0.0260892  2.71325   1.88907
# digitalisaatio         0.468107   0.167264   0.0413733   3.0056   1.42948
# ...                         ...        ...         ...      ...       ...
# yleastudio             0.803239   0.315258   0.0537508   1.3565  0.798903
# yliopisto             0.0798864    2.05885    0.267903  20.3954   1.67387
# ympäristö              0.942452  0.0564611  0.00603905  23.2485   7.90076
# yrittäjyys             0.546596   0.082447   0.0196148  1.70795   1.01214
# yrittäjät              0.185307   0.474774     0.11132  37.7912   6.31506
#
#                        eneFLOW       ASSOR
# aktiivimalli           2.37405    0.110113
# ammatillinenkoulutus   3.21287   -0.140775
# arvot                 0.632422  -0.0638994
# demokratia             1.38475  -0.0877943
# digitalisaatio        0.968934  -0.0907307
# ...                        ...         ...
# yleastudio            0.701969  0.00701685
# yliopisto             0.563569   0.0346721
# ympäristö              3.42747   0.0424479
# yrittäjyys            0.847431   -0.134687
# yrittäjät              2.27601   -0.145209
#
# [100 rows x 7 columns]

# %% [markdown]
# RW

# %%
df.sort_values(by=['RW'], ascending=False).head(15)
# Out:
#                          RW         AC         nAC  varFLOW   wasFLOW  \
# tulevaisuus               1          0           0  100.051     17.16
# sdp                       1          0           0    353.1   31.3868
# eu                        1          0           0   422977   622.006
# helsinki                  1          0           0  15.5423   2.86037
# ympäristö          0.942452  0.0564611  0.00603905  23.2485   7.90076
# maahanmuutto       0.869932   0.111925   0.0104504  213.048   20.9535
# koulutusratkaisee  0.825951    0.23146   0.0260829  26.3596    8.9627
# journalismi        0.806764   0.187809   0.0221851  8.49321   3.49969
# yleastudio         0.803239   0.315258   0.0537508   1.3565  0.798903
# sananvapaus        0.793476    0.07078   0.0110644  4.89662   2.31654
# vasemmisto         0.793079   0.177313  0.00962269  354.554   21.6075
# johtaminen         0.786619   0.186367   0.0301326  2.76024   2.27214
# maakuntauudistus   0.782892   0.175992   0.0262403  12.5893   5.41546
# vaalitentti        0.780171   0.183145   0.0172821  19.7496   6.37303
# lapset             0.770552   0.131013     0.01684  10.8962   3.44517
#
#                     eneFLOW       ASSOR
# tulevaisuus         5.15291    0.190548
# sdp                 6.94364    0.020627
# eu                  20.7012    0.760404
# helsinki            1.51391  -0.0688836
# ympäristö           3.42747   0.0424479
# maahanmuutto        5.28989   0.0319562
# koulutusratkaisee   3.65456    0.104814
# journalismi         1.89281   -0.298354
# yleastudio         0.701969  0.00701685
# sananvapaus         1.40009   0.0343616
# vasemmisto          4.53447    0.260458
# johtaminen          1.61424   0.0351114
# maakuntauudistus    2.70385   0.0680415
# vaalitentti         2.86958  -0.0679899
# lapset              1.79938  -0.0907726

# %% [markdown]
# AC

# %%
df = df.drop(["jotainrajaa", "samasuunta", "piraatit", "vaalikone"])
df.sort_values(by=["AC"], ascending=True).head(20)
# Out:
#                        RW          AC         nAC    varFLOW    wasFLOW  \
# helsinki                1           0           0    15.5423    2.86037
# tulevaisuus             1           0           0    100.051      17.16
# sdp                     1           0           0      353.1    31.3868
# eu                      1           0           0     422977    622.006
# rekry           0.0872284  0.00768261  0.00388846   0.021304  0.0140087
# urheilu          0.066778   0.0102526  0.00472183  0.0248811  0.0266758
# ilmastomarssi   0.0648379   0.0475013  0.00909193    38.0804    2.21184
# ympäristö        0.942452   0.0564611  0.00603905    23.2485    7.90076
# sananvapaus      0.793476     0.07078   0.0110644    4.89662    2.31654
# yrittäjyys       0.546596    0.082447   0.0196148    1.70795    1.01214
# eriarvoisuus    0.0376651   0.0842121   0.0255878   0.620773    0.18472
# korvaamaton   -0.00544168   0.0893158   0.0195867    128.771    8.65816
# tutkimus         0.358959   0.0987615   0.0174369    6.62457    2.09465
# ihmisoikeudet    0.147504    0.103841   0.0248588    10.2175    1.05246
# maahanmuutto     0.869932    0.111925   0.0104504    213.048    20.9535
# kasvu            0.424568    0.120891   0.0230402    4.91039    1.00337
# lapset           0.770552    0.131013     0.01684    10.8962    3.44517
# arvot            0.442593    0.131889   0.0231745    2.20834   0.964025
# tekoäly          0.234749    0.137939   0.0438063   0.193964  0.0567999
# työelämä         0.108979    0.158992    0.049081      3.413   0.873853
#
#                  eneFLOW       ASSOR
# helsinki         1.51391  -0.0688836
# tulevaisuus      5.15291    0.190548
# sdp              6.94364    0.020627
# eu               20.7012    0.760404
# rekry          0.0174136   -0.101554
# urheilu        0.0333474   -0.162432
# ilmastomarssi   0.698195     0.17755
# ympäristö        3.42747   0.0424479
# sananvapaus      1.40009   0.0343616
# yrittäjyys      0.847431   -0.134687
# eriarvoisuus    0.132191    0.061363
# korvaamaton      2.41954    -0.10422
# tutkimus         1.10058    0.110221
# ihmisoikeudet   0.570162   0.0244368
# maahanmuutto     5.28989   0.0319562
# kasvu           0.510389    0.145386
# lapset           1.79938  -0.0907726
# arvot           0.632422  -0.0638994
# tekoäly         0.076125  -0.0814939
# työelämä        0.477543 -0.00739971

# %% [markdown]
# nAC

# %%
df.sort_values(by=["nAC"], ascending=True).head(20)
# Out:
#                        RW          AC         nAC    varFLOW    wasFLOW  \
# tulevaisuus             1           0           0    100.051      17.16
# sdp                     1           0           0      353.1    31.3868
# helsinki                1           0           0    15.5423    2.86037
# eu                      1           0           0     422977    622.006
# rekry           0.0872284  0.00768261  0.00388846   0.021304  0.0140087
# urheilu          0.066778   0.0102526  0.00472183  0.0248811  0.0266758
# ympäristö        0.942452   0.0564611  0.00603905    23.2485    7.90076
# ilmastomarssi   0.0648379   0.0475013  0.00909193    38.0804    2.21184
# vasemmisto       0.793079    0.177313  0.00962269    354.554    21.6075
# maahanmuutto     0.869932    0.111925   0.0104504    213.048    20.9535
# sananvapaus      0.793476     0.07078   0.0110644    4.89662    2.31654
# oulu             0.610242    0.311136   0.0147976    158.365    16.3829
# vihapuhe         0.758892    0.161039    0.014973    31.4083    6.48616
# keskusta         0.699734    0.275951   0.0156018    182.027    21.8067
# lapset           0.770552    0.131013     0.01684    10.8962    3.44517
# vaalitentti      0.780171    0.183145   0.0172821    19.7496    6.37303
# tutkimus         0.358959   0.0987615   0.0174369    6.62457    2.09465
# ilmastolakko     0.691261    0.172927    0.017545    399.834    25.5633
# vihreät          0.687894    0.292704   0.0182964     146.65    13.0934
# korvaamaton   -0.00544168   0.0893158   0.0195867    128.771    8.65816
#
#                  eneFLOW      ASSOR
# tulevaisuus      5.15291   0.190548
# sdp              6.94364   0.020627
# helsinki         1.51391 -0.0688836
# eu               20.7012   0.760404
# rekry          0.0174136  -0.101554
# urheilu        0.0333474  -0.162432
# ympäristö        3.42747  0.0424479
# ilmastomarssi   0.698195    0.17755
# vasemmisto       4.53447   0.260458
# maahanmuutto     5.28989  0.0319562
# sananvapaus      1.40009  0.0343616
# oulu             4.22595 -0.0718644
# vihapuhe         2.56003 -0.0290201
# keskusta         5.55577  -0.131686
# lapset           1.79938 -0.0907726
# vaalitentti      2.86958 -0.0679899
# tutkimus         1.10058   0.110221
# ilmastolakko     5.43471  0.0896093
# vihreät          3.42912   0.150887
# korvaamaton      2.41954   -0.10422

# %% [markdown]
# varFLOW

# %%
df.sort_values(by=["varFLOW"], ascending=False).head(20)
# Out:
#                           RW        AC         nAC  varFLOW  wasFLOW  eneFLOW  \
# eu                         1         0           0   422977  622.006  20.7012
# ilmasto             0.455756  0.812122   0.0295599  7631.08  116.685  11.5688
# vaalit             0.0135687   3.17611   0.0601633  6079.03  62.0826  6.36876
# vaalit2019          0.229498   2.23845   0.0509844  3349.82  85.4905  10.3425
# ilmastovaalit       0.518737  0.663055   0.0670988  1655.26  68.1925  9.92796
# kokoomus            0.501194  0.778309   0.0284571  1023.13   36.953  5.99369
# ilmastonmuutos      0.652271  0.366288   0.0221728  978.459  44.2886  7.47718
# sote                0.159972   1.79885   0.0898443  587.096  30.4281  5.46102
# ilmastolakko        0.691261  0.172927    0.017545  399.834  25.5633  5.43471
# vasemmisto          0.793079  0.177313  0.00962269  354.554  21.6075  4.53447
# sdp                        1         0           0    353.1  31.3868  6.94364
# työ                  0.55207  0.823272   0.0354515   299.36  23.2273   5.2009
# nytonpakko       -0.00385707  0.235155   0.0353049   282.04  7.21075  1.75971
# eduskuntavaalit     0.536714  0.471927   0.0328709  269.418  20.3193  4.48461
# perussuomalaiset   0.0665986  0.172498   0.0196592  233.397  5.73952  1.42933
# maahanmuutto        0.869932  0.111925   0.0104504  213.048  20.9535  5.28989
# eduskunta             0.4305  0.925958   0.0411737  186.102  16.0947  4.13242
# keskusta            0.699734  0.275951   0.0156018  182.027  21.8067  5.55577
# turpo                0.11221  0.827482     0.14131  160.441  5.80285  1.46471
# oulu                0.610242  0.311136   0.0147976  158.365  16.3829  4.22595
#
#                        ASSOR
# eu                  0.760404
# ilmasto             0.210494
# vaalit            -0.0230321
# vaalit2019        -0.0683626
# ilmastovaalit       0.190223
# kokoomus           0.0131208
# ilmastonmuutos       0.16792
# sote                0.247796
# ilmastolakko       0.0896093
# vasemmisto          0.260458
# sdp                 0.020627
# työ               -0.0849568
# nytonpakko       -0.00535395
# eduskuntavaalit     0.139124
# perussuomalaiset   -0.016629
# maahanmuutto       0.0319562
# eduskunta         -0.0986638
# keskusta           -0.131686
# turpo               0.101333
# oulu              -0.0718644

# %% [markdown]
# wasFLOW

# %% [markdown]
# **TOP 25**

# %%
df.sort_values(by=["wasFLOW"], ascending=False).head(25)
# Out:
#                             RW        AC         nAC  varFLOW  wasFLOW  \
# eu                           1         0           0   422977  622.006
# ilmasto               0.455756  0.812122   0.0295599  7631.08  116.685
# vaalit2019            0.229498   2.23845   0.0509844  3349.82  85.4905
# ilmastovaalit         0.518737  0.663055   0.0670988  1655.26  68.1925
# vaalit               0.0135687   3.17611   0.0601633  6079.03  62.0826
# ilmastonmuutos        0.652271  0.366288   0.0221728  978.459  44.2886
# kokoomus              0.501194  0.778309   0.0284571  1023.13   36.953
# sdp                          1         0           0    353.1  31.3868
# sote                  0.159972   1.79885   0.0898443  587.096  30.4281
# ilmastolakko          0.691261  0.172927    0.017545  399.834  25.5633
# työ                    0.55207  0.823272   0.0354515   299.36  23.2273
# keskusta              0.699734  0.275951   0.0156018  182.027  21.8067
# vasemmisto            0.793079  0.177313  0.00962269  354.554  21.6075
# maahanmuutto          0.869932  0.111925   0.0104504  213.048  20.9535
# eduskuntavaalit       0.536714  0.471927   0.0328709  269.418  20.3193
# tulevaisuus                  1         0           0  100.051    17.16
# yle                   0.490545  0.551636   0.0278205  126.768  16.8773
# oulu                  0.610242  0.311136   0.0147976  158.365  16.3829
# eduskunta               0.4305  0.925958   0.0411737  186.102  16.0947
# politiikka            0.327291   1.23957    0.068702  127.865  14.7908
# hallitus              0.413438  0.418521   0.0387292  144.025  13.9591
# vihreät               0.687894  0.292704   0.0182964   146.65  13.0934
# eduskuntavaalit2019   0.509506  0.595253   0.0392226   156.69  12.4594
# poliisi               0.583544  0.536217   0.0386563  56.4102   10.274
# koulutustaprkl        0.436717  0.594305    0.135326  49.2083  9.71003
#
#                      eneFLOW       ASSOR
# eu                   20.7012    0.760404
# ilmasto              11.5688    0.210494
# vaalit2019           10.3425  -0.0683626
# ilmastovaalit        9.92796    0.190223
# vaalit               6.36876  -0.0230321
# ilmastonmuutos       7.47718     0.16792
# kokoomus             5.99369   0.0131208
# sdp                  6.94364    0.020627
# sote                 5.46102    0.247796
# ilmastolakko         5.43471   0.0896093
# työ                   5.2009  -0.0849568
# keskusta             5.55577   -0.131686
# vasemmisto           4.53447    0.260458
# maahanmuutto         5.28989   0.0319562
# eduskuntavaalit      4.48461    0.139124
# tulevaisuus          5.15291    0.190548
# yle                  4.66378  -0.0728368
# oulu                 4.22595  -0.0718644
# eduskunta            4.13242  -0.0986638
# politiikka           4.04064 -0.00175716
# hallitus              3.7269    0.234849
# vihreät              3.42912    0.150887
# eduskuntavaalit2019  3.00952   0.0484962
# poliisi              3.46931   -0.114533
# koulutustaprkl       3.34042 -0.00526208

# %% [markdown]
# **LEAST 15**

# %%
df.sort_values(by=["wasFLOW"], ascending=True).head(25)
# Out:
#                           RW          AC         nAC    varFLOW    wasFLOW  \
# rekry              0.0872284  0.00768261  0.00388846   0.021304  0.0140087
# urheilu             0.066778   0.0102526  0.00472183  0.0248811  0.0266758
# tampere             0.243518     0.25773   0.0549633   0.938745  0.0438479
# tekoäly             0.234749    0.137939   0.0438063   0.193964  0.0567999
# osallisuus          0.128806    0.160195   0.0484785     1.1735  0.0878507
# eriarvoisuus       0.0376651   0.0842121   0.0255878   0.620773    0.18472
# viestintä          0.0617832    0.759259    0.164128   0.808944    0.19265
# osaaminen          0.0989229    0.244574   0.0584215    2.33443   0.405596
# köyhyys             0.104756    0.459853    0.149097    4.84723   0.580578
# tasaarvo           0.0634754    0.398942   0.0853667     2.7722    0.61494
# turku               0.171271    0.435645    0.100316    2.81941   0.722531
# hyvinvointi         0.138889    0.223766   0.0342351      2.293   0.725361
# fridaysforfuture  0.00874834     0.46459    0.174912    5.70076   0.753527
# yleastudio          0.803239    0.315258   0.0537508     1.3565   0.798903
# mielenterveys       0.181182     1.48689     0.22966     15.345    0.85644
# vaalit19             0.20741    0.176563   0.0285486    2.04662   0.856817
# työelämä            0.108979    0.158992    0.049081      3.413   0.873853
# luonto             0.0499062     1.18143    0.123711    13.7527   0.935788
# arvot               0.442593    0.131889   0.0231745    2.20834   0.964025
# kasvu               0.424568    0.120891   0.0230402    4.91039    1.00337
# yrittäjyys          0.546596    0.082447   0.0196148    1.70795    1.01214
# persut              0.180694    0.214336   0.0203874     10.312    1.02542
# ihmisoikeudet       0.147504    0.103841   0.0248588    10.2175    1.05246
# turvallisuus        0.682408    0.341646   0.0541138    2.63134     1.0565
# verotus             0.315479     1.04676    0.154962    4.95994    1.05887
#
#                     eneFLOW       ASSOR
# rekry             0.0174136   -0.101554
# urheilu           0.0333474   -0.162432
# tampere           0.0390485  -0.0192153
# tekoäly            0.076125  -0.0814939
# osallisuus        0.0718782 -0.00466297
# eriarvoisuus       0.132191    0.061363
# viestintä          0.144768  -0.0347058
# osaaminen          0.351453   0.0816015
# köyhyys            0.332689   0.0127211
# tasaarvo           0.508404 -0.00763021
# turku              0.343649  -0.0684434
# hyvinvointi        0.419199  0.00667943
# fridaysforfuture    0.33042  -0.0782873
# yleastudio         0.701969  0.00701685
# mielenterveys      0.409088   -0.117284
# vaalit19           0.534548    0.102585
# työelämä           0.477543 -0.00739971
# luonto             0.423171  -0.0323139
# arvot              0.632422  -0.0638994
# kasvu              0.510389    0.145386
# yrittäjyys         0.847431   -0.134687
# persut             0.386246  -0.0399671
# ihmisoikeudet      0.570162   0.0244368
# turvallisuus       0.757107  -0.0380847
# verotus            0.512106   0.0341003

# %% [markdown]
# eneFLOW

# %%
df.sort_values(by=["eneFLOW"], ascending=False).head(15)
# Out:
#                        RW        AC        nAC  varFLOW  wasFLOW  eneFLOW  \
# eu                      1         0          0   422977  622.006  20.7012
# ilmasto          0.455756  0.812122  0.0295599  7631.08  116.685  11.5688
# vaalit2019       0.229498   2.23845  0.0509844  3349.82  85.4905  10.3425
# ilmastovaalit    0.518737  0.663055  0.0670988  1655.26  68.1925  9.92796
# ilmastonmuutos   0.652271  0.366288  0.0221728  978.459  44.2886  7.47718
# sdp                     1         0          0    353.1  31.3868  6.94364
# vaalit          0.0135687   3.17611  0.0601633  6079.03  62.0826  6.36876
# kokoomus         0.501194  0.778309  0.0284571  1023.13   36.953  5.99369
# keskusta         0.699734  0.275951  0.0156018  182.027  21.8067  5.55577
# sote             0.159972   1.79885  0.0898443  587.096  30.4281  5.46102
# ilmastolakko     0.691261  0.172927   0.017545  399.834  25.5633  5.43471
# maahanmuutto     0.869932  0.111925  0.0104504  213.048  20.9535  5.28989
# työ               0.55207  0.823272  0.0354515   299.36  23.2273   5.2009
# tulevaisuus             1         0          0  100.051    17.16  5.15291
# yle              0.490545  0.551636  0.0278205  126.768  16.8773  4.66378
#
#                     ASSOR
# eu               0.760404
# ilmasto          0.210494
# vaalit2019     -0.0683626
# ilmastovaalit    0.190223
# ilmastonmuutos    0.16792
# sdp              0.020627
# vaalit         -0.0230321
# kokoomus        0.0131208
# keskusta        -0.131686
# sote             0.247796
# ilmastolakko    0.0896093
# maahanmuutto    0.0319562
# työ            -0.0849568
# tulevaisuus      0.190548
# yle            -0.0728368

# %% [markdown]
# ASSOR

# %%
df.sort_values(by=["ASSOR"], ascending=False).head(15)
# Out:
#                         RW         AC         nAC  varFLOW  wasFLOW   eneFLOW  \
# eu                       1          0           0   422977  622.006   20.7012
# tiedevaalit       0.583163   0.544261    0.121856  12.4199  4.71591   2.21032
# vasemmisto        0.793079   0.177313  0.00962269  354.554  21.6075   4.53447
# sote              0.159972    1.79885   0.0898443  587.096  30.4281   5.46102
# hallitus          0.413438   0.418521   0.0387292  144.025  13.9591    3.7269
# ilmasto           0.455756   0.812122   0.0295599  7631.08  116.685   11.5688
# tulevaisuus              1          0           0  100.051    17.16   5.15291
# ilmastovaalit     0.518737   0.663055   0.0670988  1655.26  68.1925   9.92796
# ilmastomarssi    0.0648379  0.0475013  0.00909193  38.0804  2.21184  0.698195
# ilmastonmuutos    0.652271   0.366288   0.0221728  978.459  44.2886   7.47718
# vihreät           0.687894   0.292704   0.0182964   146.65  13.0934   3.42912
# kasvu             0.424568   0.120891   0.0230402  4.91039  1.00337  0.510389
# eduskuntavaalit   0.536714   0.471927   0.0328709  269.418  20.3193   4.48461
# tutkimus          0.358959  0.0987615   0.0174369  6.62457  2.09465   1.10058
# aktiivimalli      0.250084    1.96503    0.248907  30.6049  6.54326   2.37405
#
#                     ASSOR
# eu               0.760404
# tiedevaalit      0.377093
# vasemmisto       0.260458
# sote             0.247796
# hallitus         0.234849
# ilmasto          0.210494
# tulevaisuus      0.190548
# ilmastovaalit    0.190223
# ilmastomarssi     0.17755
# ilmastonmuutos    0.16792
# vihreät          0.150887
# kasvu            0.145386
# eduskuntavaalit  0.139124
# tutkimus         0.110221
# aktiivimalli     0.110113

# %% [markdown]
# PLOTS (Discriminative power)

# %%
polarized_flow = []
unpolarized_flow = []

polarized_ac = []
unpolarized_ac = []

polarized_rw = []
unpolarized_rw = []

for t in polarized_topics:
    polarized_flow += [core_polarization[t]["wasFLOW"]]
    polarized_ac += [core_polarization[t]["AC"]]
    polarized_rw += [core_polarization[t]["RW"]]
    
for t in unpolarized_topics:
    unpolarized_flow += [core_polarization[t]["wasFLOW"]]
    unpolarized_ac += [core_polarization[t]["AC"]]
    unpolarized_rw += [core_polarization[t]["RW"]]

# %%
plt.figure(figsize=(12,12))

plt.subplot(3,1,1)
plt.title("Random Walk")
plt.hist(polarized_rw, label="polarized", color="darkred", alpha=0.8, bins=100)
plt.hist(unpolarized_rw, label="unpolarized", alpha=0.8, bins=100)
plt.legend()

plt.subplot(3,1,2)
plt.title("Algebraic Connectivity")
plt.hist(polarized_ac, label="polarized", color="darkred", alpha=0.8, bins=100)
plt.hist(unpolarized_ac, label="unpolarized", alpha=0.8, bins=100)

plt.subplot(3,1,3)
plt.title("wasFlow Score")
plt.hist(polarized_flow, label="polarized", color="darkred", alpha=0.8, bins=100)
_ = plt.hist(unpolarized_flow, label="unpolarized", alpha=0.8, bins=100)

# %% [markdown]
# correlation between the scores

# %%
x, y, z, w, v = [], [], [], [], []
for t in core_polarization:
    x += [core_polarization[t]["varFLOW"]]
    y += [core_polarization[t]["wasFLOW"]]
    z += [core_polarization[t]["RW"]]
    w += [core_polarization[t]["AC"]]

# %%
ax = plt.subplot()
ax.scatter(x,y)
ax.set_xlim(0,1000)
ax.set_ylim(0, 100)
# Out:
# (0.0, 100.0)

# %% [markdown]
# ## STOP HERE

# %%
with PdfPages('unpolarized2_pdf.pdf') as pdf:
    
    for t in unpolarized_topics:

        plt.figure(figsize=(12,12)) 
        plt.title(t + ", RW: " + str(round(core_polarization[t]["RW"],3)) + ", ACC: " + str(round(core_polarization[t]["AC"],3)) + ", FLOW: " + str(round(core_polarization[t]["wasFLOW"],3)))
        
        #Load the network
        network = GL[topic_dict[t]][0][0][0]
        G = network.copy()
    
        # Remove self-retweets
        G.remove_edges_from(nx.selfloop_edges(G))
    
        # Find two cores
        cores = find_n_cores(G, 2)
    
        # Take core subgraph
        cm = color_cores(cores, G)
        
        nx.draw_spring(G, node_size=30, width=0.5, alpha=0.1, node_color=cm)
        pdf.savefig()
        #plt.close()

        print("Topic visualized: ", t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8b15ceef7768> in <module>
# ----> 1 with PdfPages('unpolarized2_pdf.pdf') as pdf:
#       2
#       3     for t in unpolarized_topics:
#       4
#       5         plt.figure(figsize=(12,12))
#
# NameError: name 'PdfPages' is not defined
